# %%
#Bài tập 1
import cv2
path_to_video = "dataset/dataset.mp4"
fgbg = cv2.createBackgroundSubtractorMOG2()
capture = cv2.VideoCapture(path_to_video)

# Read frames and apply background subtraction
for i in range(6):
    (grabbed, frame) = capture.read()
    fgMask = fgbg.apply(frame)

cv2.imshow('Frame', frame)
cv2.imshow('FG Mask', fgMask)
cv2.waitKey(0)
capture.release()
cv2.destroyAllWindows()
for i in range (1,5): #trick for closing the display window on macos
        cv2.waitKey(1)

#Question 1
print("Sum of intensities in fgMask is :", sum(sum(fgMask)))
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#Bài tập 2
# Since cv2 is already imported in cell 0, we don't need to import it again
capture = cv2.VideoCapture(path_to_video)

if not capture.isOpened():
    print("Error: Could not open video file")
else:
    for i in range(6):
        ret, frame = capture.read()
        if ret:
            fgMask = fgbg.apply(frame)
    
    # Apply dilation before showing the images
    fgMask = cv2.dilate(fgMask, None, iterations=2)
    
    # Show the results
    cv2.imshow('Frame', frame)
    cv2.imshow('FG Mask', fgMask)
    
    # Wait for key press and handle window closing
    key = cv2.waitKey(0) & 0xFF
    if key == 27 or key == ord('q'):  # ESC or q to quit
        pass
        
    # Clean up
    capture.release()
    cv2.destroyAllWindows()
    
    # Print the result
    print("Sum of intensities in fgMask is :", sum(sum(fgMask)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #Bài tập 2
#       2 # Since cv2 is already imported in cell 0, we don't need to import it again
# ----> 3 capture = cv2.VideoCapture(path_to_video)
#       5 if not capture.isOpened():
#       6     print("Error: Could not open video file")
#
# NameError: name 'cv2' is not defined

# %%
#Bài tập 3
import cv2
path_to_video = "dataset/dataset.mp4"
fgbg = cv2.createBackgroundSubtractorMOG2()
capture = cv2.VideoCapture(path_to_video)

for i in range(6):
    (grabbed, frame) = capture.read()
    fgMask = fgbg.apply(frame)

#Question 3
# Sử dụng kỹ thuật Dilation
fgMask = cv2.erode(fgMask, None, iterations=2)
print("Sum of intensities in fgMask is :", sum(sum(fgMask)))

cv2.imshow('Frame', frame)
cv2.imshow('FG Mask', fgMask)
cv2.waitKey(0)
capture.release()
cv2.destroyAllWindows()
for i in range (1,5): #trick for closing the display window on macos
        cv2.waitKey(1)
# Out:
# Sum of intensities in fgMask is : 17280

# %%
#Bài tập 4
import cv2
path_to_video = "dataset/dataset.mp4"
fgbg = cv2.createBackgroundSubtractorMOG2()
capture = cv2.VideoCapture(path_to_video)

for i in range(6):
    (grabbed, frame) = capture.read()
    fgMask = fgbg.apply(frame)

#Question 4
# Sử dụng kỹ thuật Dilation
fgMask = cv2.erode(fgMask, None, iterations=2)
fgMask = cv2.dilate(fgMask, None, iterations=2)
print("Sum of intensities in fgMask is :", sum(sum(fgMask)))

cv2.imshow('Frame', frame)
cv2.imshow('FG Mask', fgMask)
cv2.waitKey(0)
capture.release()
cv2.destroyAllWindows()
for i in range (1,5): #trick for closing the display window on macos
        cv2.waitKey(1)
# Out:
# Sum of intensities in fgMask is : 16047

# %%
#Bài tập 5
import cv2
path_to_video = "dataset/dataset.mp4"
fgbg = cv2.createBackgroundSubtractorMOG2()
capture = cv2.VideoCapture(path_to_video)

for i in range(100):
    (grabbed, frame) = capture.read()
    fgMask = fgbg.apply(frame)

#Question 5
# Sử dụng kỹ thuật Dilation
fgMask = cv2.threshold(fgMask, 200, 255, cv2.THRESH_BINARY)[1]
fgMask = cv2.dilate(fgMask, None, iterations=2)
fgMask = cv2.erode(fgMask, None, iterations=2)

# **************Your code here ********************


#Question 5
print("The locations of the foreground objects are: ", (contours_result))
    
cv2.imshow('Frame', frame)
cv2.imshow('FG Mask', fgMask)
cv2.waitKey(0)
capture.release()
cv2.destroyAllWindows()
for i in range (1,5): #trick for closing the display window on macos
        cv2.waitKey(1)
# Out:
# The locations of the foreground objects are:  [[319, 178]]

# %%
#Question 6
import cv2
path_to_video = "dataset/dataset.mp4"
fgbg = cv2.createBackgroundSubtractorMOG2()
capture = cv2.VideoCapture(path_to_video)

(grabbed, frame) = capture.read()
fgMask = fgbg.apply(frame)
line = 280

contours_previous  = []
people_out = 0
people_in = 0
contours_now  = []

while True:
    
    contours_now  = []
    (grabbed, frame) = capture.read()
  
    if not grabbed:
        break
   
    fgMask = fgbg.apply(frame)
    
    cv2.putText(frame, str(capture.get(cv2.CAP_PROP_POS_FRAMES)) + "/433", (15, 15),
               cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (255,0,0))
    
    fgMask = cv2.threshold(fgMask, 200, 255, cv2.THRESH_BINARY)[1]

    fgMask = cv2.dilate(fgMask, None, iterations=2)
    fgMask = cv2.erode(fgMask, None, iterations=2)
    
    contours_list, hierarchy = cv2.findContours(fgMask,
                                       cv2.RETR_TREE ,
                                       cv2.CHAIN_APPROX_SIMPLE) # Find contours
    for c in contours_list:
        if cv2.contourArea(c) < 1000:
            continue
            
        (x,y,w,h) = cv2.boundingRect(c)
        cv2.rectangle(frame, (x, y), (x+w,y+h), (0,255,0), 2)
        contours_now.append([x,y])
    
    if len(contours_previous) == 0:
        contours_previous = contours_now
        continue
        
    closest_contour_list = []
    

    # **************Your code here ********************

        
    contours_previous = contours_now
    
                        
    cv2.line(frame, (0,line), (frame.shape[1], line), (0,255,255), 2)
    cv2.putText(frame,"People out: " +str(people_out), (15,40), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0,0,255), 2)
    cv2.putText(frame,"People in: " +str(people_in), (14,80), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0,0,255),2 )

    #show the current frame and the fg masks
    cv2.imshow('Frame', frame)
    cv2.imshow('FG Mask', fgMask)
    ## [show]

    keyboard = cv2.waitKey(0)
    if keyboard == 'q' or keyboard == 27:
        break
        
capture.release()
cv2.destroyAllWindows()
for i in range (1,5): #trick for closing the display window on macos
        cv2.waitKey(1)
